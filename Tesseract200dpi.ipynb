# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
import io

# ตั้งค่าเส้นทางของ Tesseract (ถ้าจำเป็น)
# pytesseract.pytesseract.tesseract_cmd = r'/path/to/tesseract'

# โหลด PDF
pdf_path = 'Calendar_KPS_2567.pdf'
pdf_document = fitz.open(pdf_path)

# อ่านทุกหน้าของ PDF
for page_number in range(pdf_document.page_count):
    page = pdf_document.load_page(page_number)
    
    # แปลงหน้า PDF เป็นรูปภาพ (เพิ่ม DPI)
    pix = page.get_pixmap(dpi=200)
    img_data = pix.tobytes("png")
    img = Image.open(io.BytesIO(img_data))
    
    # แปลงภาพเป็นระดับสีเทา
    img = img.convert('L')
    
    # เพิ่มความคมชัด
    enhancer = ImageEnhance.Contrast(img)
    img = enhancer.enhance(2)

    # ใช้ Tesseract OCR ในการอ่านข้อความ
    custom_oem_psm_config = r'--oem 3 --psm 6'  # ใช้ OCR Engine Mode 3 (default) และ Page Segmentation Mode 6 (สำหรับบล็อคข้อความ)
    text = pytesseract.image_to_string(img, lang='tha+eng', config=custom_oem_psm_config)
    
    print(f"ข้อความจากหน้า {page_number + 1}:")
    print(text)

pdf_document.close()
# Out:
# ข้อความจากหน้า 1:
# son
# @   ปฏิทินการศึกษา ปีการศึกษา 2567 สําหรับนิสิตระดับปริญญาตรี มหาวิทยาลัยเกษตรศาสตร์ วิทยาเขตกําแพงแสน
# กําหนดการ                                 ภาคต้น                ภาคปลาย         ภาคฤดูร้อน ปี พ.ศ. 2568
#
# > นิสิตใหม่ : สอบวัดผลภาษาอังกฤษเพื่อจัดชั้นเรียน (KET 1) ผ่านระบบ exam.ku.th                  รอบที่ 1 (TCAS 1-2)
#
# อ. 7 - พฤ. 16 พ.ค. 67
#
# รอบที่ 2 (TCAS 3)
#
# อ.4-อ.11 มิ.ย.67
#
# รอบที่ 3 (TCAS 4)
#
# อ.11 - ศ. 14 มิ.ย. 67
# 9 ฉิสิตใหม่ : ขึ้นทะเบียนเป็นนิสิตใหม่ออนไลน์ ผ่านระบบ https://isea.ku.ac.th/STDWeb           อ.4 - จ. 10 มิ.ย. 67 (TCAS 1-2)
# และลงทะเบียนยืนยันตัวบุคคลเพื่อใช้งานบัญชีผู้ใช้เครือข่ายนนทรี  (Nontri Account)                 a. 7- W. 12 มิ.ย.67 (TCAS 3)
# ของมหาวิทยาลัยเกษตรศาสตร์ ผ่านระบบ https://accounts.ku.ac.th                             อ.11 - wa. 13 มิ.ย. 67 (TCAS 4)
# > นฉิสิตใหม่ : ใช้บัญชีผู้ใช้เครือข่ายนนทรี (Nontri Account) ที่ได้รับ ดําเนินการ Login                   อ.4 - ศ. 14 มิ.ย. 67
# เข้าระบบลงทะเบียนนิสิต my.ku.th เพื่อพิมพ์ใบชําระเงินค่าธรรมเนียมการศึกษาผ่าน                        (TCAS 1-4)
# Mobile Banking
# ๑ วันชําระเงินค่าธรรมเนียมการศึกษาผ่านธนาคาร                                                  จ. 3 - อา. 16 มิ.ย. 67                จ. 4 - อา. 17 พ.ย. 67              จ. 7 - พฤ.10 เม.ย. 68
# ee
# 9 นิสิตที่มีหนี้สินค้างชําระ เนื่องจากกู้ยืมเงินจากกองทุน กรอ. และ กยศ. ไม่เพียงพอ                   จ. 3 - อา. 16 มิ.ย. 67                จ. 4 - อา. 17 พ.ย. 67              จ. 7 - พฤ.10 เม.ย. 68
# ทัดณะเหลสมนิตลิเณ | 7 | 0 | |
# > นิสิตที่มีเหตุจําเป็นไม่สามารถชําระเงินค่าธรรมเนียมการศึกษาได้ ให้ทําคําร้องขอ                 จ.3-ศ. 14 มิ.ย. 67                 จ.4 - ศ. 15 พ.ย. 67               จ. 7 - พฤ. 10 เม.ย. 68
# แผนนยกณาหนงศีรทัพลกรณเสอตกพอ | | | 7 0-
# รณ์ณ์ ศศ”ศศฬ-”ฬไร ได 7
# 9 นิสิตที่มีคะแนนเฉลี่ยสะสมตํากว่า 2.00 ต้องเข้าพบอาจารย์ที่ปรึกษา ก่อนการลงทะเบียนเรียน         จ. 3 - อา. 16 มิ.ย. 67               จ.4 - อา. 17 พ.ย. 67
# เพณัเท่รัตอนกกมณ์ | | mens | ไฝ์0
# รณ์นร์ฑ์ณับ 7 | ณะ |  - |
# ร๓ 00000ไ1 5๓ ๆ
#
# ข้อความจากหน้า 2:
# 2
#      as               a                     0         " 0                  ta            °
# ay)    ปฏิทินการศึกษา ปีการศึกษา 2567 สําหรับนิสิตระดับปรัญญาตรี มหาวทยาลยเกษตรศาสตร วทยาเขตกาแพงแสน
# ๐                                                                        ซี                                                                 ฆย
# กาหนดการ                                                     ภาคตน                          ภาคปลาย               ภาคฤดูรอน U พ.ศ. 2568
#
# > วันลงทะเบียนเรียนผ่านระบบสารสนเทศบริหารการศึกษา (ทษ.เ๒.[ก) สําหรับนิสิตที่ชําระเงินผ่าน              อ. 18- ศ. 21 มิ.ย. 67                อ. 19 - ศ. 22 พ.ย. 67             พฤ. 17 - ศ. 18 เม.ย. 68
# ธนาคารแล้วก่อน 2 วันทําการ (นิสิตต้องตรวจสอบวัน-เวลาลงทะเบียนอีกครั้งที่ระบบ my.ku.th)
#
# - นิสิตรหัส 64 และน้อยกว่า                                                                          อ. 18 มิ.ย. 67                        อ. 19 พ.ย. 67                     พฤ. 17 เม.ย. 68
#
# - นิสิตรหัส 65                                                                                   พ. 19 มิ.ย. 67                     พฤ. 21 พ.ย. 67                   พฤ. 17 เม.ย. 68
#
# - นิสิตรหัส 66                                                                                      พฤ. 20 มิ.ย. 67                       ศ. 22 พ.ย. 67                      ศ. 18 เม.ย. 68
#
# - นิสิตรหัส 67                                                                                     ศ. 21 มิ.ย. 67                       พ. 20 พ.ย. 67                     ศ. 18 เม.ย. 68
# เหมายเหตุ :
# 1) นิสิตสามารถลงทะเบียนเรียนได้ตั้งแต่เวลา 10.00-16.00 ตามวันและเวลาที่กําหนดให้
# 2) กรณีที่นิสิตไม่สามารถลงทะเบียนเรียนได้ทันตามเวลาที่กําหนดให้ในวันนั้นๆ นิสิตสามารถลงทะเบียนเรียนได้อีกครั้ง
# ตั้งแต่เวลา 18.00 น. จนถึง 00.00 น.
# > โครงการก้าวแรกสู่ศาสตร์แห่งแผ่นดิน                                                           พฤะ-20-มิะซะ-67
#
# อ.18 - Wa. 20 มิ.ย. 67
#
# > วันสุดท้ายของการจัดทํารายละเอียดของรายวิชาออนไลน์ (มคอ.3) และรายละเอียด ของ           อา. 23 มิ.ย. 67                    อา. 24 พ.ย. 67
# ประสบการณ์ภาคสนามออนไลน์ (มคอ.4)
# > วันเปิดภาคการศึกษา (วันเริมการสอน) **                                                         จ. 24 มิ.ย. 67                       จ. 25 พ.ย. 67                     จ. 21 เม.ย. 68
# ๑ วันเริมคิดค่าปรับการลงทะเบียนเรียนล่าช้า และชําระเงินล่าช้าผ่านระบบระบบสารสนเทศ
# บริหารการศึกษา (my.ku.th)
# ๑ วันลงทะเบียนเรียนสําหรับนิสิตที่ชําระเงินผ่านธนาคารล่าช้า และลงทะเบียนเรียนไม่ทัน               จ. 24 - ศ. 28 มิ.ย. 67               จ. 25 - ศ. 29 พ.ย. 67              จ. 21 - ศ. 25 เม.ย. 68
# ตามวันและเวลาที่กําหนดให้ ผ่านระบบสารสนเทศบริหารการศึกษา (my.ku.th)
# ๑ วันเปลี่ยนแปลงรายวิชา (Add/Drop) ผ่านระบบสารสนเทศบริหารการศึกษา (my.ku.th)
# SD งานเกษตรกําแพงแสน (ดูประกาศมหาวิทยาลัยอีกครั้ง และไม่งดการเรียนการสอน)          | 0 7077       อา. 1 - อ.10 ธ.ค. 67       รคคคลรเง|
#
# ข้อความจากหน้า 3:
# 3
#
# สต an               a                     ow 0ิ270         a. ae                  4๑            °
#
# KA:  อ    ปฏิทินการศึกษา ปีการศึกษา 2567 สําหรับนิสิตระดับปรัญญาตรี มหาวทยาลยเกษตรศาสตร วทยาเขตกาแพงแสน
#
# Nee
#
# °                                                                        2                                                                 as
# กาหนดการ                                                     ภาคตน                          ภาคปลาย               ภาคฤดูรอน U พ.ศ. 2568
#
# ๑ วันลงทะเบียนเรียนสําหรับนิสิตที่ชําระเงินผ่านธนาคารล่าช้า และลงทะเบียนเรียนไม่ทัน                 จ.1-ศ.5 ก.ค.67                  จ.2-ศ. 6 ธ.ค. 67              จ. 28 เม.ย. - ศ. 2 พ.ค. 68
# ตามวันและเวลาที่กําหนดให้ ผ่านระบบสารสนเทศบริหารการศึกษา (my.ku.th)                              (โดยต้องผ่านความเห็นชอบ                  (โดยต้องผ่านความเห็นชอบ                (โดยต้องผ่านความเห็นชอบ
# D> วันเปลี่ยนแปลงรายวิซา (Add/Drop) KU3 online ผ่านระบบสารสนเทศบริหารการศึกษา                จากอาจารย์ผู้สอน)                     จากอาจารย์ผู้สอน)                    จากอาจารย์ผู้สอน)
# (my.ku.th)
# D วันเริมพิมพ์ใบเสร็จรับเงิน (KU2) ออนไลน์ ผ่านระบบสารสนเทศบริหารการศึกษา (my.ku.th)              นิสิตสามารถพิมพ์ได้ในวันถัดไปหลังจากชําระเงินค่าธรรมเนียมการศึกษาเรียบร้อยแล้ว
# % โครงการเกษตราบูชาตรู (รันไหว้ค2                                                           หลกศ์ meet    | 0 078วร[[[
# ๑ วันขอถอนวิชาเรียนบางรายวิชาโดยไม่บันทึกอักษร W ในใบรายงานผลการศึกษา                      ส. 6 - a. 23 ก.ค. 67                  ส.7- อ. 24 ธ.ค. 67                ส. 3 - อ. 20 พ.ค. 68
# ผ่านระบบสารสนเทศบริหารการศึกษา (my.ku.th)
# ๑ วันคัดชื่อออกและพันสภาพการเป็นนิสิต ตามข้อบังคับฯ ว่าด้วยการศึกษาระดับปริญญาตรี                 จ. 8 ก.ค. 67                        จ. 9 ธ.ค. 67
# มหาวิทยาลัยเกษตรศาสตร์ พุทธศักราช 2566
# ๑ วันบันทึกขอจบการศึกษา สําหรับนิสิตที่คาดว่าจะจบการศึกษา                                    จ.8- a. 23 ก.ค. 67                 จ.9 - อ. 24 ธ.ค. 67                อ. 6 - อ. 20 พ.ค. 68
# ผ่านระบบ และหลังบันทึกเสร็จให้พิมพ์เอกสารใบขอจบส่งคณะต้นสังกัด
# D วันเริมคิดค่าธรรมเนียมขอจบล่าช้า                                                           พ. 24 ก.ค. 67                     พ. 25 ธ.ค. 67                    พ. 21 พ.ค. 68
# ๑ วันขอถอนวิชาเรียนบางรายวิชา โดยบันทึกอักษร W ในใบรายงานผลการศึกษา ผ่านระบบ       พ. 24 ก.ค. - พฤ. 22 ส.ค. 67        พ. 25 ธ.ค. 67 - พฤ. 23 ม.ค. 68
# สารสนเทศบริหารการศึกษา (my.ku.th)
# หมายเหตุ : หากดําเนินการเรียบร้อยแล้ว นิสิตต้องพิมพ์รายงานการลงทะเบียนเรียนเก็บไว้เป็นหลักฐาน
# SD อาจารย์ดูสรุปผลประเมินการสอนของนิสิตผ่านเว็บ ครังที่ 1                                           จ. 19 ส.ค. 67                      จ. 20 ม.ค. 68           Po
#            หลสด                     กยดล           | 0ฏ717 |
#
# ข้อความจากหน้า 4:
# 4
# (§ Ps เน3     aA      a     ae     a            ๐   waa   ๓ ow ปริ       a     a     ow               ca          ๐
# ay)   ปฏิทินการ  กษา ปีการศึกษา 2567 สําหรบนสตระดบ  รญญาตรมหาวท ยาลยเกษตรศาสตร วทยาเขตกาแพงแสน
# ๐                                                                        ซี                                                                 ฆ
# กาหนดการ                                                     ภาคตน                          ภาคปลาย               ภาคฤดูรอน ปี พ.ศ. 2568
# ๑ วันขอถอนวิชาเรียนบางรายวิชาผ่านระบบ โดยบันทึกอักษร W ในใบรายงานผลการศึกษา            ศ. 23 aA. - จ. 2 ก.ย. 67             ศ. 24 ม.ค. - จ. 3 ก.พ. 68
# (ต้องผ่านความเห็นชอบจากอาจารย์ผู้สอนและอาจารย์ที่ปรึกษา
# ๑ วันขอถอนวิชาเรียนบางรายวิชาผ่านระบบ โดยบันทึกอักษร W ในใบรายงานผลการศึกษา            a. 3 ก.ุย. - พ. 9 ต.ค. 67             อ. 4 ก.พ. - พฤ. 6 มี.ค. 68
# eo         «                 ee               ed ia          ate
# (ต้องผ่านความเห็นชอบจากอาจารย์ผู้สอนและอาจารย์ที่ปรึกษา) และมีค่าปรับ
# ๑ วันซ้อมย่อยและซ้อมใหญ่พิธีพระราชทานปริญญาบัตร (ไม่งดการเรียนการสอน)                         พ.2-ส.5ต.ค.67
# (ดูประกาศมหาวิทยาลัยอีกครั้ง และไม่งดการเรียนการสอน)
#
# > วันพิธีพระราชทานปริญญาบัตร (ดูประกาศมหาวิทยาลัยอีกครัง)                                      จ7หล0ดด67        | 0ว3ว ว. ..]
# > วันสุดท้ายของการขอเทียบรายวิชาสําหรับนิสิตเข้าใหม่ และนิสิตโครงการเรียนล่วงหน้า                   พ.9 ต.ค. 67           | 7>» | 7>2 |
# ๑ นิสิตกรอกแบบประเมินการสอนผ่านเว็บ ครังที่ 2                                                จ. 14 - ศ.18 ต.ค. 67                จ. 10 - ศ. 14 มี.ค. 68
# ๑ อาจารย์กรอกแบบประเมินตนเองผ่านเว็บ
# ๑ วันสุดท้ายของการส่งใบขอจบการศึกษาล่าช้า ถึงกองบริหารการศึกษา                                 ศ. 18 ต.ค. 67                       ศ. 14 มี.ค. 68                     ศ. 30 พ.ค. 68
# ๑ วันสุดท้ายของการส่งเอกสารขอลาพักการศึกษา ถึงกองบริหารการศึกษา
# D วันสุดท้ายของการสอนนิสิตระดับปริญญาตรี
#
# นิสิตภาคปกติ                                                                                   ศ. 18 ต.ค. 67                       ศ. 14 มี.ค. 68                      ศ. 30 พ.ค. 68
#
# นิสิตภาคพิเศษ                                                                                  อา. 20 ต.ค. 67                      อา. 16 มี.ค.68                      ศ. 30 พ.ค. 68
# ๑ วันสอบไล่ **                                                                              จ. 21 ต.ค. - ศ. 1 พ.ย. 67              จ. 17 - ศ. 28 มี.ค 68             ส. 31 พ.ค- จ. 2 มิ.ย. 68
# ๑ วันปิดภาคการศึกษา (วันจบการศึกษา) **                                                       จ.4 พ.ย. 67                       จ. 31 มี.ค. 68                     พ.4 มิ.ย. 68
# > วันสุดท้ายของการบันทึกข้อมูลกิจกรรมเสริมหลักสูตรของนิสิตทีจะจบการศึกษา                                                                                                 พ.4มิ.ย. 68
# > วันสุดท้ายของการยืนผลการทดสอบภาษาอังกฤษสําหรับนิสิตทีไม่ได้เข้าทดสอบตามทีมหาวิทยาลัย
# กําหนด
#
# ข้อความจากหน้า 5:
# 5
#
# ส
#
# รัศัศเนอ     As      a     a     a           ๑   waa     ow ปริ       a     a     ow               ga         ๐
#
# ง  น    ปฏิทินการ  กษา ปีการศึกษา 2567 สําหรับนิสิตระดับ  รญญาตร มหาวทยาลยเกษตรศาสตร วทยาเขตกาแพงแสน
#
# °                                                                        2                                                                 va
# กาหนดการ                                                    ภาคตน                         ภาคปลาย               ภาคฤดูรอน U พ.ศ. 2568
# > วันทดสอบวัดความรู้ความสามารถด้านภาษาอังกฤษ สําหรับนิสิตที่จะสําเร็จการศึกษา                ช่วงเดือน มิ.ย. - ส.ค. 67
# ระดับปริญญาตรี มหาวิทยาลัยเกษตรศาสตร์ (Exit-Exam)                                              *เฉพาะนิสิตรหัส 65 (หลักสูตร 4 ปี) และ
# นิสิตรหัส 64 (หลักสูตร 5 ปี และหลักสูตร
# 6 ปี)
# (ดูประกาศมหาวิทยาลัยอีกครั้ง)
# ธน 000 0๐๒ 80 0 7 3
# > อาจารย์ดูสรุปผลประเมินการสอนของนิสิตผ่านเว็บ ครังที่ 2                                         ศ. 15 พ.ย. 67                     ศ. 11 เม.ย. 68          สศรศร
# ๑ วันสุดท้ายของการเปลี่ยนแปลงคะแนนสําหรับนิสิตที่ขอจบการศึกษา                               จ. 18 พ.ย. 67                     จ. 21 เม.ย. 68                    พฤ. 19 มิ.ย. 68
# > วันสุดท้ายของการรายงานผลการดําเนินงานของรายวิชาออนไลน์ (มคอ.5)                                 พ.4 ธ.ค. 67                        พ. 30 เม.ย. 68
# และรายงานผลการดําเนินการของประสบการณ์ภาคสนามออนไลน์ (มคอ.6)
# 9 วันสุดท้ายของการแก้ไขคะแนน | และ ผ หากไม่ปฏิบัติตามนีให้ถือว่านิสิตสอบตก                     พ. 11 ธ.ค. 67                      Wa). 8 พ.ค. 68                     จ. 14 ก.ค. 68
# (คะแนน F) โดยอัตโนมัติ
# > วันสุดท้ายของการรายงานผลการดําเนินการของหลักสูตร (มคอ.7)                           | 0 077ั7            ศ. 30 พ.ค. 68            สศรเง
# จัดทําโดย
# งานบริหารหลักสูตรและยุทธศาสตร์การศึกษา กองบริหารการศึกษา
# วันพุธที่ 5มิถุนายน พ.ศ. 2567
